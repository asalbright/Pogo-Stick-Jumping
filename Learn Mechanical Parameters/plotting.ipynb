# %% [markdown]
# ## Imports

# %%
import csv
import re
import glob
import datetime
from pathlib import Path
import pandas
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import tkinter as tk
from tkinter import simpledialog
print(matplotlib.matplotlib_fname())

from pogo_stick_jumping.jumping_ODE_Nonlinear import PogoODEnonlinear
# Out:
# C:\Users\andre\.matplotlib\matplotlibrc

# %% [markdown]
# ## Save Figures Flag

# %%
SAVE_FIG = True

# %% [markdown]
# ## Get Data Paths

# %%
ROOT = tk.Tk()
ROOT.withdraw()
title = "File Location"
prompt = "Enter the path to the evaluation data: "
# Get path from user
path = simpledialog.askstring(title, prompt)
# If user closes program
if path is None:
    raise Exception("File path is does not exit or user closed program.")
    sys.exit()
# If user enters non-existant path
save_path = Path(path)
if not os.path.exists(save_path):
    raise Exception("File path is does not exit or user closed program.")
    sys.exit()
# Set the paths according to how they should be saved
data_path = save_path / "plotting_data"
save_path = save_path / "figures"
# Make the save path if it does not exits
if not os.path.exists(save_path): os.makedirs(save_path)
# If the models path does not exist or is named wrong
if not os.path.exists(data_path):
    raise Exception("Plotting Data path does not exist or name of models file is not 'models'.")
    sys.exit()
# Print what the models path defined and the save path defined
print(f"\nThe data will be queued from:\n {data_path}\n")
print(f"The figures will be saved to:\n {save_path}")
# Out:
# The data will be queued from:
#  training_data\2021_09_24\plotting_data
#
# The figures will be saved to:
#  training_data\2021_09_24\figures

# %% [markdown]
# ## Import the Data from Path

# %%
# sort the files read in
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

files = sorted(glob.glob(str(data_path / '*.csv')), key=numericalSort)

print(f'Number of Agents found: {len(files)}\n')

# organize the data into dictionaries
# data = []                                                                                   # array to store agent data
file_names = []                                                                             # list to store file names for naming agents in dict
data = None
for f in files:
    file_name = os.path.basename(f)                                                         # get file name and split it up by
    file_name = re.split('[_ .]', file_name)
    # uncomment print statement to determine what numbers are needed in file_name
    print("Split file name: " , file_name, "\n")
    file_name = f"{file_name[1]}-{file_name[2]}"                                            # choose the parts of file name you want to keep using the previous print statment
    file_names.append(file_name)                                                            # add the agents name to the list of file names
    df = pandas.read_csv(f)                                                                 # read in the first .csv file
    df = df.transpose()
    print("Data from file shape: ", df.shape)
    # Change the header to be the first and second rows combined
    new_header = df.iloc[0] + '_' + df.iloc[1] + '_' + df.iloc[2]  #grab the first row for the header
    # Take the data below the header rows
    df = df[3:1003] 
    # Set the header row as the df header
    df.columns = new_header
    if data is None:
        data = df
        print("Initial shape: " , data.shape)
    else:
        data = pandas.concat([data, df], axis=1)
        print("Final shape: " , data.shape)
data
# Out:
# Number of Agents found: 2
#
# Split file name:  ['all', 'result', 'max', 'csv']
#
# Data from file shape:  (1004, 1800)
# Initial shape:  (1000, 1800)
# Split file name:  ['all', 'result', 'spec', 'csv']
#
# Data from file shape:  (1004, 1800)
# Final shape:  (1000, 3600)
#     RewardHeight_1031_log_1_ep_max_height_value  \
# 0                                      0.094088
# 1                                      0.091622
# 2                                      0.077052
# 3                                      0.067609
# 4                                      0.079119
# ..                                          ...
# 995                                    0.113394
# 996                                    0.113333
# 997                                    0.113333
# 998                                    0.113379
# 999                                    0.113379
#
#     RewardHeight_1031_log_1_ep_max_height_wall_time  \
# 0                                 1632453608.470721
# 1                                  1632453609.08808
# 2                                  1632453609.61745
# 3                                 1632453610.204701
# 4                                 1632453610.748892
# ..                                              ...
# 995                               1632454237.742158
# 996                               1632454238.345185
# 997                               1632454239.096318
# 998                               1632454239.792347
# 999                               1632454240.402817
#
#     RewardHeight_1031_log_1_ep_spring_k_value  \
# 0                                 3463.601562
# 1                                 2478.665771
# 2                                  1929.39563
# 3                                 5082.068848
# 4                                  2122.80957
# ..                                        ...
# 995                               3594.630371
# 996                               3605.262207
# 997                               3605.262207
# 998                                3597.13501
# 999                                3597.13501
#
#     RewardHeight_1031_log_1_ep_spring_k_wall_time  \
# 0                                 1632453608.4708
# 1                               1632453609.088137
# 2                               1632453609.617533
# 3                               1632453610.204764
# 4                               1632453610.748953
# ..                                            ...
# 995                             1632454237.742225
# 996                             1632454238.345246
# 997                             1632454239.096379
# 998                             1632454239.792425
# 999                             1632454240.402898
#
#     RewardHeight_1031_log_1_ep_zeta_value  \
# 0                                0.057104
# 1                                0.033918
# 2                                0.069071
# 3                                 0.12123
# 4                                0.075752
# ..                                    ...
# 995                              0.007556
# 996                              0.007557
# 997                              0.007557
# 998                              0.007556
# 999                              0.007556
#
#     RewardHeight_1031_log_1_ep_zeta_wall_time  \
# 0                           1632453608.470838
# 1                           1632453609.088165
# 2                            1632453609.61758
# 3                           1632453610.204793
# 4                           1632453610.748984
# ..                                        ...
# 995                         1632454237.742254
# 996                         1632454238.345274
# 997                         1632454239.096406
# 998                         1632454239.792464
# 999                         1632454240.402938
#
#     RewardHeight_1031_log_1_rollout/ep_len_mean_value  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 1.0
# ..                                                ...
# 995                                               NaN
# 996                                               1.0
# 997                                               NaN
# 998                                               NaN
# 999                                               NaN
#
#     RewardHeight_1031_log_1_rollout/ep_len_mean_wall_time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                    1632453610.205372
# ..                                                 ...
# 995                                                NaN
# 996                                  1632454237.742847
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#     RewardHeight_1031_log_1_rollout/ep_rew_mean_value  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                            0.082593
# ..                                                ...
# 995                                               NaN
# 996                                           0.11347
# 997                                               NaN
# 998                                               NaN
# 999                                               NaN
#
#     RewardHeight_1031_log_1_rollout/ep_rew_mean_wall_time  ...  \
# 0                                                  NaN     ...
# 1                                                  NaN     ...
# 2                                                  NaN     ...
# 3                                                  NaN     ...
# 4                                     1632453610.20543     ...
# ..                                                 ...     ...
# 995                                                NaN     ...
# 996                                  1632454237.742893     ...
# 997                                                NaN     ...
# 998                                                NaN     ...
# 999                                                NaN     ...
#
#     RewardSpecifiedHeight_9993_log_1_rollout/ep_rew_mean_value  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                             0.794305
# ..                                                 ...
# 995                                                NaN
# 996                                           0.975112
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#     RewardSpecifiedHeight_9993_log_1_rollout/ep_rew_mean_wall_time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                     1632439546.23798
# ..                                                 ...
# 995                                                NaN
# 996                                  1632440299.300631
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#     RewardSpecifiedHeight_9993_log_1_time/fps_value  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               1.0
# ..                                              ...
# 995                                             NaN
# 996                                             1.0
# 997                                             NaN
# 998                                             NaN
# 999                                             NaN
#
#     RewardSpecifiedHeight_9993_log_1_time/fps_wall_time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                    1632439546.238016
# ..                                                 ...
# 995                                                NaN
# 996                                  1632440299.300658
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#     RewardSpecifiedHeight_9993_log_1_train/critic_loss_value  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                           0.000058
# 996                                           0.000374
# 997                                           0.000049
# 998                                           0.000237
# 999                                           0.000232
#
#     RewardSpecifiedHeight_9993_log_1_train/critic_loss_wall_time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                  1632440299.299769
# 996                                  1632440299.981304
# 997                                  1632440300.772908
# 998                                  1632440301.489235
# 999                                  1632440302.153821
#
#     RewardSpecifiedHeight_9993_log_1_train/learning_rate_value  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                              0.001
# 996                                              0.001
# 997                                              0.001
# 998                                              0.001
# 999                                              0.001
#
#     RewardSpecifiedHeight_9993_log_1_train/learning_rate_wall_time  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                   1632440299.29979
# 996                                  1632440299.981351
# 997                                   1632440300.77294
# 998                                  1632440301.489266
# 999                                  1632440302.153857
#
#     RewardSpecifiedHeight_9993_log_1_train/actor_loss_value  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                          -0.971463
# 997                                                NaN
# 998                                          -0.971816
# 999                                                NaN
#
#     RewardSpecifiedHeight_9993_log_1_train/actor_loss_wall_time
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                  1632440299.981257
# 997                                                NaN
# 998                                  1632440301.489203
# 999                                                NaN
#
# [1000 rows x 3600 columns]

# %% [markdown]
# ## Remove unused Data:

# %%
training_cases = ["RewardHeight", "RewardSpecifiedHeight"]
data_values = ["ep_max_height_value", "ep_spring_k_value", "ep_zeta_value", "ep_rew_mean_value"]

# Drop unused data from dataframe
print("Dataframe shape before: ", data.shape)
drop_names = []
for column in data:
    if not any(data_values in column for data_values in data_values):
        print(column)
        drop_names.append(str(column))
data = data.drop(columns=drop_names)
print("Dataframe shape after: ", data.shape)
# Out:
# Dataframe shape before:  (1000, 3600)
# RewardHeight_1031_log_1_ep_max_height_wall_time
# RewardHeight_1031_log_1_ep_spring_k_wall_time
# RewardHeight_1031_log_1_ep_zeta_wall_time
# RewardHeight_1031_log_1_rollout/ep_len_mean_value
# RewardHeight_1031_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1031_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1031_log_1_time/fps_value
# RewardHeight_1031_log_1_time/fps_wall_time
# RewardHeight_1031_log_1_train/critic_loss_value
# RewardHeight_1031_log_1_train/critic_loss_wall_time
# RewardHeight_1031_log_1_train/learning_rate_value
# RewardHeight_1031_log_1_train/learning_rate_wall_time
# RewardHeight_1031_log_1_train/actor_loss_value
# RewardHeight_1031_log_1_train/actor_loss_wall_time
# RewardHeight_1042_log_1_ep_max_height_wall_time
# RewardHeight_1042_log_1_ep_spring_k_wall_time
# RewardHeight_1042_log_1_ep_zeta_wall_time
# RewardHeight_1042_log_1_rollout/ep_len_mean_value
# RewardHeight_1042_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1042_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1042_log_1_time/fps_value
# RewardHeight_1042_log_1_time/fps_wall_time
# RewardHeight_1042_log_1_train/critic_loss_value
# RewardHeight_1042_log_1_train/critic_loss_wall_time
# RewardHeight_1042_log_1_train/learning_rate_value
# RewardHeight_1042_log_1_train/learning_rate_wall_time
# RewardHeight_1042_log_1_train/actor_loss_value
# RewardHeight_1042_log_1_train/actor_loss_wall_time
# RewardHeight_1074_log_1_ep_max_height_wall_time
# RewardHeight_1074_log_1_ep_spring_k_wall_time
# RewardHeight_1074_log_1_ep_zeta_wall_time
# RewardHeight_1074_log_1_rollout/ep_len_mean_value
# RewardHeight_1074_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1074_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1074_log_1_time/fps_value
# RewardHeight_1074_log_1_time/fps_wall_time
# RewardHeight_1074_log_1_train/critic_loss_value
# RewardHeight_1074_log_1_train/critic_loss_wall_time
# RewardHeight_1074_log_1_train/learning_rate_value
# RewardHeight_1074_log_1_train/learning_rate_wall_time
# RewardHeight_1074_log_1_train/actor_loss_value
# RewardHeight_1074_log_1_train/actor_loss_wall_time
# RewardHeight_119_log_1_ep_max_height_wall_time
# RewardHeight_119_log_1_ep_spring_k_wall_time
# RewardHeight_119_log_1_ep_zeta_wall_time
# RewardHeight_119_log_1_rollout/ep_len_mean_value
# RewardHeight_119_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_119_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_119_log_1_time/fps_value
# RewardHeight_119_log_1_time/fps_wall_time
# RewardHeight_119_log_1_train/critic_loss_value
# RewardHeight_119_log_1_train/critic_loss_wall_time
# RewardHeight_119_log_1_train/learning_rate_value
# RewardHeight_119_log_1_train/learning_rate_wall_time
# RewardHeight_119_log_1_train/actor_loss_value
# RewardHeight_119_log_1_train/actor_loss_wall_time
# RewardHeight_1201_log_1_ep_max_height_wall_time
# RewardHeight_1201_log_1_ep_spring_k_wall_time
# RewardHeight_1201_log_1_ep_zeta_wall_time
# RewardHeight_1201_log_1_rollout/ep_len_mean_value
# RewardHeight_1201_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1201_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1201_log_1_time/fps_value
# RewardHeight_1201_log_1_time/fps_wall_time
# RewardHeight_1201_log_1_train/critic_loss_value
# RewardHeight_1201_log_1_train/critic_loss_wall_time
# RewardHeight_1201_log_1_train/learning_rate_value
# RewardHeight_1201_log_1_train/learning_rate_wall_time
# RewardHeight_1201_log_1_train/actor_loss_value
# RewardHeight_1201_log_1_train/actor_loss_wall_time
# RewardHeight_1300_log_1_ep_max_height_wall_time
# RewardHeight_1300_log_1_ep_spring_k_wall_time
# RewardHeight_1300_log_1_ep_zeta_wall_time
# RewardHeight_1300_log_1_rollout/ep_len_mean_value
# RewardHeight_1300_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1300_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1300_log_1_time/fps_value
# RewardHeight_1300_log_1_time/fps_wall_time
# RewardHeight_1300_log_1_train/critic_loss_value
# RewardHeight_1300_log_1_train/critic_loss_wall_time
# RewardHeight_1300_log_1_train/learning_rate_value
# RewardHeight_1300_log_1_train/learning_rate_wall_time
# RewardHeight_1300_log_1_train/actor_loss_value
# RewardHeight_1300_log_1_train/actor_loss_wall_time
# RewardHeight_1337_log_1_ep_max_height_wall_time
# RewardHeight_1337_log_1_ep_spring_k_wall_time
# RewardHeight_1337_log_1_ep_zeta_wall_time
# RewardHeight_1337_log_1_rollout/ep_len_mean_value
# RewardHeight_1337_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1337_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1337_log_1_time/fps_value
# RewardHeight_1337_log_1_time/fps_wall_time
# RewardHeight_1337_log_1_train/critic_loss_value
# RewardHeight_1337_log_1_train/critic_loss_wall_time
# RewardHeight_1337_log_1_train/learning_rate_value
# RewardHeight_1337_log_1_train/learning_rate_wall_time
# RewardHeight_1337_log_1_train/actor_loss_value
# RewardHeight_1337_log_1_train/actor_loss_wall_time
# RewardHeight_1385_log_1_ep_max_height_wall_time
# RewardHeight_1385_log_1_ep_spring_k_wall_time
# RewardHeight_1385_log_1_ep_zeta_wall_time
# RewardHeight_1385_log_1_rollout/ep_len_mean_value
# RewardHeight_1385_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1385_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1385_log_1_time/fps_value
# RewardHeight_1385_log_1_time/fps_wall_time
# RewardHeight_1385_log_1_train/critic_loss_value
# RewardHeight_1385_log_1_train/critic_loss_wall_time
# RewardHeight_1385_log_1_train/learning_rate_value
# RewardHeight_1385_log_1_train/learning_rate_wall_time
# RewardHeight_1385_log_1_train/actor_loss_value
# RewardHeight_1385_log_1_train/actor_loss_wall_time
# RewardHeight_1397_log_1_ep_max_height_wall_time
# RewardHeight_1397_log_1_ep_spring_k_wall_time
# RewardHeight_1397_log_1_ep_zeta_wall_time
# RewardHeight_1397_log_1_rollout/ep_len_mean_value
# RewardHeight_1397_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1397_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1397_log_1_time/fps_value
# RewardHeight_1397_log_1_time/fps_wall_time
# RewardHeight_1397_log_1_train/critic_loss_value
# RewardHeight_1397_log_1_train/critic_loss_wall_time
# RewardHeight_1397_log_1_train/learning_rate_value
# RewardHeight_1397_log_1_train/learning_rate_wall_time
# RewardHeight_1397_log_1_train/actor_loss_value
# RewardHeight_1397_log_1_train/actor_loss_wall_time
# RewardHeight_1457_log_1_ep_max_height_wall_time
# RewardHeight_1457_log_1_ep_spring_k_wall_time
# RewardHeight_1457_log_1_ep_zeta_wall_time
# RewardHeight_1457_log_1_rollout/ep_len_mean_value
# RewardHeight_1457_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1457_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1457_log_1_time/fps_value
# RewardHeight_1457_log_1_time/fps_wall_time
# RewardHeight_1457_log_1_train/critic_loss_value
# RewardHeight_1457_log_1_train/critic_loss_wall_time
# RewardHeight_1457_log_1_train/learning_rate_value
# RewardHeight_1457_log_1_train/learning_rate_wall_time
# RewardHeight_1457_log_1_train/actor_loss_value
# RewardHeight_1457_log_1_train/actor_loss_wall_time
# RewardHeight_1545_log_1_ep_max_height_wall_time
# RewardHeight_1545_log_1_ep_spring_k_wall_time
# RewardHeight_1545_log_1_ep_zeta_wall_time
# RewardHeight_1545_log_1_rollout/ep_len_mean_value
# RewardHeight_1545_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1545_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1545_log_1_time/fps_value
# RewardHeight_1545_log_1_time/fps_wall_time
# RewardHeight_1545_log_1_train/critic_loss_value
# RewardHeight_1545_log_1_train/critic_loss_wall_time
# RewardHeight_1545_log_1_train/learning_rate_value
# RewardHeight_1545_log_1_train/learning_rate_wall_time
# RewardHeight_1545_log_1_train/actor_loss_value
# RewardHeight_1545_log_1_train/actor_loss_wall_time
# RewardHeight_163_log_1_ep_max_height_wall_time
# RewardHeight_163_log_1_ep_spring_k_wall_time
# RewardHeight_163_log_1_ep_zeta_wall_time
# RewardHeight_163_log_1_rollout/ep_len_mean_value
# RewardHeight_163_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_163_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_163_log_1_time/fps_value
# RewardHeight_163_log_1_time/fps_wall_time
# RewardHeight_163_log_1_train/critic_loss_value
# RewardHeight_163_log_1_train/critic_loss_wall_time
# RewardHeight_163_log_1_train/learning_rate_value
# RewardHeight_163_log_1_train/learning_rate_wall_time
# RewardHeight_163_log_1_train/actor_loss_value
# RewardHeight_163_log_1_train/actor_loss_wall_time
# RewardHeight_1742_log_1_ep_max_height_wall_time
# RewardHeight_1742_log_1_ep_spring_k_wall_time
# RewardHeight_1742_log_1_ep_zeta_wall_time
# RewardHeight_1742_log_1_rollout/ep_len_mean_value
# RewardHeight_1742_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1742_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1742_log_1_time/fps_value
# RewardHeight_1742_log_1_time/fps_wall_time
# RewardHeight_1742_log_1_train/critic_loss_value
# RewardHeight_1742_log_1_train/critic_loss_wall_time
# RewardHeight_1742_log_1_train/learning_rate_value
# RewardHeight_1742_log_1_train/learning_rate_wall_time
# RewardHeight_1742_log_1_train/actor_loss_value
# RewardHeight_1742_log_1_train/actor_loss_wall_time
# RewardHeight_1772_log_1_ep_max_height_wall_time
# RewardHeight_1772_log_1_ep_spring_k_wall_time
# RewardHeight_1772_log_1_ep_zeta_wall_time
# RewardHeight_1772_log_1_rollout/ep_len_mean_value
# RewardHeight_1772_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1772_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1772_log_1_time/fps_value
# RewardHeight_1772_log_1_time/fps_wall_time
# RewardHeight_1772_log_1_train/critic_loss_value
# RewardHeight_1772_log_1_train/critic_loss_wall_time
# RewardHeight_1772_log_1_train/learning_rate_value
# RewardHeight_1772_log_1_train/learning_rate_wall_time
# RewardHeight_1772_log_1_train/actor_loss_value
# RewardHeight_1772_log_1_train/actor_loss_wall_time
# RewardHeight_1925_log_1_ep_max_height_wall_time
# RewardHeight_1925_log_1_ep_spring_k_wall_time
# RewardHeight_1925_log_1_ep_zeta_wall_time
# RewardHeight_1925_log_1_rollout/ep_len_mean_value
# RewardHeight_1925_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_1925_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_1925_log_1_time/fps_value
# RewardHeight_1925_log_1_time/fps_wall_time
# RewardHeight_1925_log_1_train/critic_loss_value
# RewardHeight_1925_log_1_train/critic_loss_wall_time
# RewardHeight_1925_log_1_train/learning_rate_value
# RewardHeight_1925_log_1_train/learning_rate_wall_time
# RewardHeight_1925_log_1_train/actor_loss_value
# RewardHeight_1925_log_1_train/actor_loss_wall_time
# RewardHeight_2046_log_1_ep_max_height_wall_time
# RewardHeight_2046_log_1_ep_spring_k_wall_time
# RewardHeight_2046_log_1_ep_zeta_wall_time
# RewardHeight_2046_log_1_rollout/ep_len_mean_value
# RewardHeight_2046_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2046_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2046_log_1_time/fps_value
# RewardHeight_2046_log_1_time/fps_wall_time
# RewardHeight_2046_log_1_train/critic_loss_value
# RewardHeight_2046_log_1_train/critic_loss_wall_time
# RewardHeight_2046_log_1_train/learning_rate_value
# RewardHeight_2046_log_1_train/learning_rate_wall_time
# RewardHeight_2046_log_1_train/actor_loss_value
# RewardHeight_2046_log_1_train/actor_loss_wall_time
# RewardHeight_2052_log_1_ep_max_height_wall_time
# RewardHeight_2052_log_1_ep_spring_k_wall_time
# RewardHeight_2052_log_1_ep_zeta_wall_time
# RewardHeight_2052_log_1_rollout/ep_len_mean_value
# RewardHeight_2052_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2052_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2052_log_1_time/fps_value
# RewardHeight_2052_log_1_time/fps_wall_time
# RewardHeight_2052_log_1_train/critic_loss_value
# RewardHeight_2052_log_1_train/critic_loss_wall_time
# RewardHeight_2052_log_1_train/learning_rate_value
# RewardHeight_2052_log_1_train/learning_rate_wall_time
# RewardHeight_2052_log_1_train/actor_loss_value
# RewardHeight_2052_log_1_train/actor_loss_wall_time
# RewardHeight_2117_log_1_ep_max_height_wall_time
# RewardHeight_2117_log_1_ep_spring_k_wall_time
# RewardHeight_2117_log_1_ep_zeta_wall_time
# RewardHeight_2117_log_1_rollout/ep_len_mean_value
# RewardHeight_2117_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2117_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2117_log_1_time/fps_value
# RewardHeight_2117_log_1_time/fps_wall_time
# RewardHeight_2117_log_1_train/critic_loss_value
# RewardHeight_2117_log_1_train/critic_loss_wall_time
# RewardHeight_2117_log_1_train/learning_rate_value
# RewardHeight_2117_log_1_train/learning_rate_wall_time
# RewardHeight_2117_log_1_train/actor_loss_value
# RewardHeight_2117_log_1_train/actor_loss_wall_time
# RewardHeight_2206_log_1_ep_max_height_wall_time
# RewardHeight_2206_log_1_ep_spring_k_wall_time
# RewardHeight_2206_log_1_ep_zeta_wall_time
# RewardHeight_2206_log_1_rollout/ep_len_mean_value
# RewardHeight_2206_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2206_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2206_log_1_time/fps_value
# RewardHeight_2206_log_1_time/fps_wall_time
# RewardHeight_2206_log_1_train/critic_loss_value
# RewardHeight_2206_log_1_train/critic_loss_wall_time
# RewardHeight_2206_log_1_train/learning_rate_value
# RewardHeight_2206_log_1_train/learning_rate_wall_time
# RewardHeight_2206_log_1_train/actor_loss_value
# RewardHeight_2206_log_1_train/actor_loss_wall_time
# RewardHeight_2208_log_1_ep_max_height_wall_time
# RewardHeight_2208_log_1_ep_spring_k_wall_time
# RewardHeight_2208_log_1_ep_zeta_wall_time
# RewardHeight_2208_log_1_rollout/ep_len_mean_value
# RewardHeight_2208_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2208_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2208_log_1_time/fps_value
# RewardHeight_2208_log_1_time/fps_wall_time
# RewardHeight_2208_log_1_train/critic_loss_value
# RewardHeight_2208_log_1_train/critic_loss_wall_time
# RewardHeight_2208_log_1_train/learning_rate_value
# RewardHeight_2208_log_1_train/learning_rate_wall_time
# RewardHeight_2208_log_1_train/actor_loss_value
# RewardHeight_2208_log_1_train/actor_loss_wall_time
# RewardHeight_2210_log_1_ep_max_height_wall_time
# RewardHeight_2210_log_1_ep_spring_k_wall_time
# RewardHeight_2210_log_1_ep_zeta_wall_time
# RewardHeight_2210_log_1_rollout/ep_len_mean_value
# RewardHeight_2210_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2210_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2210_log_1_time/fps_value
# RewardHeight_2210_log_1_time/fps_wall_time
# RewardHeight_2210_log_1_train/critic_loss_value
# RewardHeight_2210_log_1_train/critic_loss_wall_time
# RewardHeight_2210_log_1_train/learning_rate_value
# RewardHeight_2210_log_1_train/learning_rate_wall_time
# RewardHeight_2210_log_1_train/actor_loss_value
# RewardHeight_2210_log_1_train/actor_loss_wall_time
# RewardHeight_2233_log_1_ep_max_height_wall_time
# RewardHeight_2233_log_1_ep_spring_k_wall_time
# RewardHeight_2233_log_1_ep_zeta_wall_time
# RewardHeight_2233_log_1_rollout/ep_len_mean_value
# RewardHeight_2233_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2233_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2233_log_1_time/fps_value
# RewardHeight_2233_log_1_time/fps_wall_time
# RewardHeight_2233_log_1_train/critic_loss_value
# RewardHeight_2233_log_1_train/critic_loss_wall_time
# RewardHeight_2233_log_1_train/learning_rate_value
# RewardHeight_2233_log_1_train/learning_rate_wall_time
# RewardHeight_2233_log_1_train/actor_loss_value
# RewardHeight_2233_log_1_train/actor_loss_wall_time
# RewardHeight_2244_log_1_ep_max_height_wall_time
# RewardHeight_2244_log_1_ep_spring_k_wall_time
# RewardHeight_2244_log_1_ep_zeta_wall_time
# RewardHeight_2244_log_1_rollout/ep_len_mean_value
# RewardHeight_2244_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2244_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2244_log_1_time/fps_value
# RewardHeight_2244_log_1_time/fps_wall_time
# RewardHeight_2244_log_1_train/critic_loss_value
# RewardHeight_2244_log_1_train/critic_loss_wall_time
# RewardHeight_2244_log_1_train/learning_rate_value
# RewardHeight_2244_log_1_train/learning_rate_wall_time
# RewardHeight_2244_log_1_train/actor_loss_value
# RewardHeight_2244_log_1_train/actor_loss_wall_time
# RewardHeight_2403_log_1_ep_max_height_wall_time
# RewardHeight_2403_log_1_ep_spring_k_wall_time
# RewardHeight_2403_log_1_ep_zeta_wall_time
# RewardHeight_2403_log_1_rollout/ep_len_mean_value
# RewardHeight_2403_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2403_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2403_log_1_time/fps_value
# RewardHeight_2403_log_1_time/fps_wall_time
# RewardHeight_2403_log_1_train/critic_loss_value
# RewardHeight_2403_log_1_train/critic_loss_wall_time
# RewardHeight_2403_log_1_train/learning_rate_value
# RewardHeight_2403_log_1_train/learning_rate_wall_time
# RewardHeight_2403_log_1_train/actor_loss_value
# RewardHeight_2403_log_1_train/actor_loss_wall_time
# RewardHeight_2435_log_1_ep_max_height_wall_time
# RewardHeight_2435_log_1_ep_spring_k_wall_time
# RewardHeight_2435_log_1_ep_zeta_wall_time
# RewardHeight_2435_log_1_rollout/ep_len_mean_value
# RewardHeight_2435_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2435_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2435_log_1_time/fps_value
# RewardHeight_2435_log_1_time/fps_wall_time
# RewardHeight_2435_log_1_train/critic_loss_value
# RewardHeight_2435_log_1_train/critic_loss_wall_time
# RewardHeight_2435_log_1_train/learning_rate_value
# RewardHeight_2435_log_1_train/learning_rate_wall_time
# RewardHeight_2435_log_1_train/actor_loss_value
# RewardHeight_2435_log_1_train/actor_loss_wall_time
# RewardHeight_2504_log_1_ep_max_height_wall_time
# RewardHeight_2504_log_1_ep_spring_k_wall_time
# RewardHeight_2504_log_1_ep_zeta_wall_time
# RewardHeight_2504_log_1_rollout/ep_len_mean_value
# RewardHeight_2504_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2504_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2504_log_1_time/fps_value
# RewardHeight_2504_log_1_time/fps_wall_time
# RewardHeight_2504_log_1_train/critic_loss_value
# RewardHeight_2504_log_1_train/critic_loss_wall_time
# RewardHeight_2504_log_1_train/learning_rate_value
# RewardHeight_2504_log_1_train/learning_rate_wall_time
# RewardHeight_2504_log_1_train/actor_loss_value
# RewardHeight_2504_log_1_train/actor_loss_wall_time
# RewardHeight_2652_log_1_ep_max_height_wall_time
# RewardHeight_2652_log_1_ep_spring_k_wall_time
# RewardHeight_2652_log_1_ep_zeta_wall_time
# RewardHeight_2652_log_1_rollout/ep_len_mean_value
# RewardHeight_2652_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_2652_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_2652_log_1_time/fps_value
# RewardHeight_2652_log_1_time/fps_wall_time
# RewardHeight_2652_log_1_train/critic_loss_value
# RewardHeight_2652_log_1_train/critic_loss_wall_time
# RewardHeight_2652_log_1_train/learning_rate_value
# RewardHeight_2652_log_1_train/learning_rate_wall_time
# RewardHeight_2652_log_1_train/actor_loss_value
# RewardHeight_2652_log_1_train/actor_loss_wall_time
# RewardHeight_3026_log_1_ep_max_height_wall_time
# RewardHeight_3026_log_1_ep_spring_k_wall_time
# RewardHeight_3026_log_1_ep_zeta_wall_time
# RewardHeight_3026_log_1_rollout/ep_len_mean_value
# RewardHeight_3026_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3026_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3026_log_1_time/fps_value
# RewardHeight_3026_log_1_time/fps_wall_time
# RewardHeight_3026_log_1_train/critic_loss_value
# RewardHeight_3026_log_1_train/critic_loss_wall_time
# RewardHeight_3026_log_1_train/learning_rate_value
# RewardHeight_3026_log_1_train/learning_rate_wall_time
# RewardHeight_3026_log_1_train/actor_loss_value
# RewardHeight_3026_log_1_train/actor_loss_wall_time
# RewardHeight_3339_log_1_ep_max_height_wall_time
# RewardHeight_3339_log_1_ep_spring_k_wall_time
# RewardHeight_3339_log_1_ep_zeta_wall_time
# RewardHeight_3339_log_1_rollout/ep_len_mean_value
# RewardHeight_3339_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3339_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3339_log_1_time/fps_value
# RewardHeight_3339_log_1_time/fps_wall_time
# RewardHeight_3339_log_1_train/critic_loss_value
# RewardHeight_3339_log_1_train/critic_loss_wall_time
# RewardHeight_3339_log_1_train/learning_rate_value
# RewardHeight_3339_log_1_train/learning_rate_wall_time
# RewardHeight_3339_log_1_train/actor_loss_value
# RewardHeight_3339_log_1_train/actor_loss_wall_time
# RewardHeight_3467_log_1_ep_max_height_wall_time
# RewardHeight_3467_log_1_ep_spring_k_wall_time
# RewardHeight_3467_log_1_ep_zeta_wall_time
# RewardHeight_3467_log_1_rollout/ep_len_mean_value
# RewardHeight_3467_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3467_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3467_log_1_time/fps_value
# RewardHeight_3467_log_1_time/fps_wall_time
# RewardHeight_3467_log_1_train/critic_loss_value
# RewardHeight_3467_log_1_train/critic_loss_wall_time
# RewardHeight_3467_log_1_train/learning_rate_value
# RewardHeight_3467_log_1_train/learning_rate_wall_time
# RewardHeight_3467_log_1_train/actor_loss_value
# RewardHeight_3467_log_1_train/actor_loss_wall_time
# RewardHeight_3497_log_1_ep_max_height_wall_time
# RewardHeight_3497_log_1_ep_spring_k_wall_time
# RewardHeight_3497_log_1_ep_zeta_wall_time
# RewardHeight_3497_log_1_rollout/ep_len_mean_value
# RewardHeight_3497_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3497_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3497_log_1_time/fps_value
# RewardHeight_3497_log_1_time/fps_wall_time
# RewardHeight_3497_log_1_train/critic_loss_value
# RewardHeight_3497_log_1_train/critic_loss_wall_time
# RewardHeight_3497_log_1_train/learning_rate_value
# RewardHeight_3497_log_1_train/learning_rate_wall_time
# RewardHeight_3497_log_1_train/actor_loss_value
# RewardHeight_3497_log_1_train/actor_loss_wall_time
# RewardHeight_3593_log_1_ep_max_height_wall_time
# RewardHeight_3593_log_1_ep_spring_k_wall_time
# RewardHeight_3593_log_1_ep_zeta_wall_time
# RewardHeight_3593_log_1_rollout/ep_len_mean_value
# RewardHeight_3593_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3593_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3593_log_1_time/fps_value
# RewardHeight_3593_log_1_time/fps_wall_time
# RewardHeight_3593_log_1_train/critic_loss_value
# RewardHeight_3593_log_1_train/critic_loss_wall_time
# RewardHeight_3593_log_1_train/learning_rate_value
# RewardHeight_3593_log_1_train/learning_rate_wall_time
# RewardHeight_3593_log_1_train/actor_loss_value
# RewardHeight_3593_log_1_train/actor_loss_wall_time
# RewardHeight_3693_log_1_ep_max_height_wall_time
# RewardHeight_3693_log_1_ep_spring_k_wall_time
# RewardHeight_3693_log_1_ep_zeta_wall_time
# RewardHeight_3693_log_1_rollout/ep_len_mean_value
# RewardHeight_3693_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3693_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3693_log_1_time/fps_value
# RewardHeight_3693_log_1_time/fps_wall_time
# RewardHeight_3693_log_1_train/critic_loss_value
# RewardHeight_3693_log_1_train/critic_loss_wall_time
# RewardHeight_3693_log_1_train/learning_rate_value
# RewardHeight_3693_log_1_train/learning_rate_wall_time
# RewardHeight_3693_log_1_train/actor_loss_value
# RewardHeight_3693_log_1_train/actor_loss_wall_time
# RewardHeight_3800_log_1_ep_max_height_wall_time
# RewardHeight_3800_log_1_ep_spring_k_wall_time
# RewardHeight_3800_log_1_ep_zeta_wall_time
# RewardHeight_3800_log_1_rollout/ep_len_mean_value
# RewardHeight_3800_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3800_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3800_log_1_time/fps_value
# RewardHeight_3800_log_1_time/fps_wall_time
# RewardHeight_3800_log_1_train/critic_loss_value
# RewardHeight_3800_log_1_train/critic_loss_wall_time
# RewardHeight_3800_log_1_train/learning_rate_value
# RewardHeight_3800_log_1_train/learning_rate_wall_time
# RewardHeight_3800_log_1_train/actor_loss_value
# RewardHeight_3800_log_1_train/actor_loss_wall_time
# RewardHeight_3817_log_1_ep_max_height_wall_time
# RewardHeight_3817_log_1_ep_spring_k_wall_time
# RewardHeight_3817_log_1_ep_zeta_wall_time
# RewardHeight_3817_log_1_rollout/ep_len_mean_value
# RewardHeight_3817_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3817_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3817_log_1_time/fps_value
# RewardHeight_3817_log_1_time/fps_wall_time
# RewardHeight_3817_log_1_train/critic_loss_value
# RewardHeight_3817_log_1_train/critic_loss_wall_time
# RewardHeight_3817_log_1_train/learning_rate_value
# RewardHeight_3817_log_1_train/learning_rate_wall_time
# RewardHeight_3817_log_1_train/actor_loss_value
# RewardHeight_3817_log_1_train/actor_loss_wall_time
# RewardHeight_3947_log_1_ep_max_height_wall_time
# RewardHeight_3947_log_1_ep_spring_k_wall_time
# RewardHeight_3947_log_1_ep_zeta_wall_time
# RewardHeight_3947_log_1_rollout/ep_len_mean_value
# RewardHeight_3947_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3947_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3947_log_1_time/fps_value
# RewardHeight_3947_log_1_time/fps_wall_time
# RewardHeight_3947_log_1_train/critic_loss_value
# RewardHeight_3947_log_1_train/critic_loss_wall_time
# RewardHeight_3947_log_1_train/learning_rate_value
# RewardHeight_3947_log_1_train/learning_rate_wall_time
# RewardHeight_3947_log_1_train/actor_loss_value
# RewardHeight_3947_log_1_train/actor_loss_wall_time
# RewardHeight_3971_log_1_ep_max_height_wall_time
# RewardHeight_3971_log_1_ep_spring_k_wall_time
# RewardHeight_3971_log_1_ep_zeta_wall_time
# RewardHeight_3971_log_1_rollout/ep_len_mean_value
# RewardHeight_3971_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3971_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3971_log_1_time/fps_value
# RewardHeight_3971_log_1_time/fps_wall_time
# RewardHeight_3971_log_1_train/critic_loss_value
# RewardHeight_3971_log_1_train/critic_loss_wall_time
# RewardHeight_3971_log_1_train/learning_rate_value
# RewardHeight_3971_log_1_train/learning_rate_wall_time
# RewardHeight_3971_log_1_train/actor_loss_value
# RewardHeight_3971_log_1_train/actor_loss_wall_time
# RewardHeight_3983_log_1_ep_max_height_wall_time
# RewardHeight_3983_log_1_ep_spring_k_wall_time
# RewardHeight_3983_log_1_ep_zeta_wall_time
# RewardHeight_3983_log_1_rollout/ep_len_mean_value
# RewardHeight_3983_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_3983_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_3983_log_1_time/fps_value
# RewardHeight_3983_log_1_time/fps_wall_time
# RewardHeight_3983_log_1_train/critic_loss_value
# RewardHeight_3983_log_1_train/critic_loss_wall_time
# RewardHeight_3983_log_1_train/learning_rate_value
# RewardHeight_3983_log_1_train/learning_rate_wall_time
# RewardHeight_3983_log_1_train/actor_loss_value
# RewardHeight_3983_log_1_train/actor_loss_wall_time
# RewardHeight_4166_log_1_ep_max_height_wall_time
# RewardHeight_4166_log_1_ep_spring_k_wall_time
# RewardHeight_4166_log_1_ep_zeta_wall_time
# RewardHeight_4166_log_1_rollout/ep_len_mean_value
# RewardHeight_4166_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4166_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4166_log_1_time/fps_value
# RewardHeight_4166_log_1_time/fps_wall_time
# RewardHeight_4166_log_1_train/critic_loss_value
# RewardHeight_4166_log_1_train/critic_loss_wall_time
# RewardHeight_4166_log_1_train/learning_rate_value
# RewardHeight_4166_log_1_train/learning_rate_wall_time
# RewardHeight_4166_log_1_train/actor_loss_value
# RewardHeight_4166_log_1_train/actor_loss_wall_time
# RewardHeight_4188_log_1_ep_max_height_wall_time
# RewardHeight_4188_log_1_ep_spring_k_wall_time
# RewardHeight_4188_log_1_ep_zeta_wall_time
# RewardHeight_4188_log_1_rollout/ep_len_mean_value
# RewardHeight_4188_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4188_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4188_log_1_time/fps_value
# RewardHeight_4188_log_1_time/fps_wall_time
# RewardHeight_4188_log_1_train/critic_loss_value
# RewardHeight_4188_log_1_train/critic_loss_wall_time
# RewardHeight_4188_log_1_train/learning_rate_value
# RewardHeight_4188_log_1_train/learning_rate_wall_time
# RewardHeight_4188_log_1_train/actor_loss_value
# RewardHeight_4188_log_1_train/actor_loss_wall_time
# RewardHeight_4267_log_1_ep_max_height_wall_time
# RewardHeight_4267_log_1_ep_spring_k_wall_time
# RewardHeight_4267_log_1_ep_zeta_wall_time
# RewardHeight_4267_log_1_rollout/ep_len_mean_value
# RewardHeight_4267_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4267_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4267_log_1_time/fps_value
# RewardHeight_4267_log_1_time/fps_wall_time
# RewardHeight_4267_log_1_train/critic_loss_value
# RewardHeight_4267_log_1_train/critic_loss_wall_time
# RewardHeight_4267_log_1_train/learning_rate_value
# RewardHeight_4267_log_1_train/learning_rate_wall_time
# RewardHeight_4267_log_1_train/actor_loss_value
# RewardHeight_4267_log_1_train/actor_loss_wall_time
# RewardHeight_4354_log_1_ep_max_height_wall_time
# RewardHeight_4354_log_1_ep_spring_k_wall_time
# RewardHeight_4354_log_1_ep_zeta_wall_time
# RewardHeight_4354_log_1_rollout/ep_len_mean_value
# RewardHeight_4354_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4354_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4354_log_1_time/fps_value
# RewardHeight_4354_log_1_time/fps_wall_time
# RewardHeight_4354_log_1_train/critic_loss_value
# RewardHeight_4354_log_1_train/critic_loss_wall_time
# RewardHeight_4354_log_1_train/learning_rate_value
# RewardHeight_4354_log_1_train/learning_rate_wall_time
# RewardHeight_4354_log_1_train/actor_loss_value
# RewardHeight_4354_log_1_train/actor_loss_wall_time
# RewardHeight_4365_log_1_ep_max_height_wall_time
# RewardHeight_4365_log_1_ep_spring_k_wall_time
# RewardHeight_4365_log_1_ep_zeta_wall_time
# RewardHeight_4365_log_1_rollout/ep_len_mean_value
# RewardHeight_4365_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4365_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4365_log_1_time/fps_value
# RewardHeight_4365_log_1_time/fps_wall_time
# RewardHeight_4365_log_1_train/critic_loss_value
# RewardHeight_4365_log_1_train/critic_loss_wall_time
# RewardHeight_4365_log_1_train/learning_rate_value
# RewardHeight_4365_log_1_train/learning_rate_wall_time
# RewardHeight_4365_log_1_train/actor_loss_value
# RewardHeight_4365_log_1_train/actor_loss_wall_time
# RewardHeight_4370_log_1_ep_max_height_wall_time
# RewardHeight_4370_log_1_ep_spring_k_wall_time
# RewardHeight_4370_log_1_ep_zeta_wall_time
# RewardHeight_4370_log_1_rollout/ep_len_mean_value
# RewardHeight_4370_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4370_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4370_log_1_time/fps_value
# RewardHeight_4370_log_1_time/fps_wall_time
# RewardHeight_4370_log_1_train/critic_loss_value
# RewardHeight_4370_log_1_train/critic_loss_wall_time
# RewardHeight_4370_log_1_train/learning_rate_value
# RewardHeight_4370_log_1_train/learning_rate_wall_time
# RewardHeight_4370_log_1_train/actor_loss_value
# RewardHeight_4370_log_1_train/actor_loss_wall_time
# RewardHeight_4396_log_1_ep_max_height_wall_time
# RewardHeight_4396_log_1_ep_spring_k_wall_time
# RewardHeight_4396_log_1_ep_zeta_wall_time
# RewardHeight_4396_log_1_rollout/ep_len_mean_value
# RewardHeight_4396_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4396_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4396_log_1_time/fps_value
# RewardHeight_4396_log_1_time/fps_wall_time
# RewardHeight_4396_log_1_train/critic_loss_value
# RewardHeight_4396_log_1_train/critic_loss_wall_time
# RewardHeight_4396_log_1_train/learning_rate_value
# RewardHeight_4396_log_1_train/learning_rate_wall_time
# RewardHeight_4396_log_1_train/actor_loss_value
# RewardHeight_4396_log_1_train/actor_loss_wall_time
# RewardHeight_4545_log_1_ep_max_height_wall_time
# RewardHeight_4545_log_1_ep_spring_k_wall_time
# RewardHeight_4545_log_1_ep_zeta_wall_time
# RewardHeight_4545_log_1_rollout/ep_len_mean_value
# RewardHeight_4545_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4545_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4545_log_1_time/fps_value
# RewardHeight_4545_log_1_time/fps_wall_time
# RewardHeight_4545_log_1_train/critic_loss_value
# RewardHeight_4545_log_1_train/critic_loss_wall_time
# RewardHeight_4545_log_1_train/learning_rate_value
# RewardHeight_4545_log_1_train/learning_rate_wall_time
# RewardHeight_4545_log_1_train/actor_loss_value
# RewardHeight_4545_log_1_train/actor_loss_wall_time
# RewardHeight_463_log_1_ep_max_height_wall_time
# RewardHeight_463_log_1_ep_spring_k_wall_time
# RewardHeight_463_log_1_ep_zeta_wall_time
# RewardHeight_463_log_1_rollout/ep_len_mean_value
# RewardHeight_463_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_463_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_463_log_1_time/fps_value
# RewardHeight_463_log_1_time/fps_wall_time
# RewardHeight_463_log_1_train/critic_loss_value
# RewardHeight_463_log_1_train/critic_loss_wall_time
# RewardHeight_463_log_1_train/learning_rate_value
# RewardHeight_463_log_1_train/learning_rate_wall_time
# RewardHeight_463_log_1_train/actor_loss_value
# RewardHeight_463_log_1_train/actor_loss_wall_time
# RewardHeight_4811_log_1_ep_max_height_wall_time
# RewardHeight_4811_log_1_ep_spring_k_wall_time
# RewardHeight_4811_log_1_ep_zeta_wall_time
# RewardHeight_4811_log_1_rollout/ep_len_mean_value
# RewardHeight_4811_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4811_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4811_log_1_time/fps_value
# RewardHeight_4811_log_1_time/fps_wall_time
# RewardHeight_4811_log_1_train/critic_loss_value
# RewardHeight_4811_log_1_train/critic_loss_wall_time
# RewardHeight_4811_log_1_train/learning_rate_value
# RewardHeight_4811_log_1_train/learning_rate_wall_time
# RewardHeight_4811_log_1_train/actor_loss_value
# RewardHeight_4811_log_1_train/actor_loss_wall_time
# RewardHeight_4870_log_1_ep_max_height_wall_time
# RewardHeight_4870_log_1_ep_spring_k_wall_time
# RewardHeight_4870_log_1_ep_zeta_wall_time
# RewardHeight_4870_log_1_rollout/ep_len_mean_value
# RewardHeight_4870_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4870_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4870_log_1_time/fps_value
# RewardHeight_4870_log_1_time/fps_wall_time
# RewardHeight_4870_log_1_train/critic_loss_value
# RewardHeight_4870_log_1_train/critic_loss_wall_time
# RewardHeight_4870_log_1_train/learning_rate_value
# RewardHeight_4870_log_1_train/learning_rate_wall_time
# RewardHeight_4870_log_1_train/actor_loss_value
# RewardHeight_4870_log_1_train/actor_loss_wall_time
# RewardHeight_4873_log_1_ep_max_height_wall_time
# RewardHeight_4873_log_1_ep_spring_k_wall_time
# RewardHeight_4873_log_1_ep_zeta_wall_time
# RewardHeight_4873_log_1_rollout/ep_len_mean_value
# RewardHeight_4873_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4873_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4873_log_1_time/fps_value
# RewardHeight_4873_log_1_time/fps_wall_time
# RewardHeight_4873_log_1_train/critic_loss_value
# RewardHeight_4873_log_1_train/critic_loss_wall_time
# RewardHeight_4873_log_1_train/learning_rate_value
# RewardHeight_4873_log_1_train/learning_rate_wall_time
# RewardHeight_4873_log_1_train/actor_loss_value
# RewardHeight_4873_log_1_train/actor_loss_wall_time
# RewardHeight_4948_log_1_ep_max_height_wall_time
# RewardHeight_4948_log_1_ep_spring_k_wall_time
# RewardHeight_4948_log_1_ep_zeta_wall_time
# RewardHeight_4948_log_1_rollout/ep_len_mean_value
# RewardHeight_4948_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4948_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4948_log_1_time/fps_value
# RewardHeight_4948_log_1_time/fps_wall_time
# RewardHeight_4948_log_1_train/critic_loss_value
# RewardHeight_4948_log_1_train/critic_loss_wall_time
# RewardHeight_4948_log_1_train/learning_rate_value
# RewardHeight_4948_log_1_train/learning_rate_wall_time
# RewardHeight_4948_log_1_train/actor_loss_value
# RewardHeight_4948_log_1_train/actor_loss_wall_time
# RewardHeight_4974_log_1_ep_max_height_wall_time
# RewardHeight_4974_log_1_ep_spring_k_wall_time
# RewardHeight_4974_log_1_ep_zeta_wall_time
# RewardHeight_4974_log_1_rollout/ep_len_mean_value
# RewardHeight_4974_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4974_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4974_log_1_time/fps_value
# RewardHeight_4974_log_1_time/fps_wall_time
# RewardHeight_4974_log_1_train/critic_loss_value
# RewardHeight_4974_log_1_train/critic_loss_wall_time
# RewardHeight_4974_log_1_train/learning_rate_value
# RewardHeight_4974_log_1_train/learning_rate_wall_time
# RewardHeight_4974_log_1_train/actor_loss_value
# RewardHeight_4974_log_1_train/actor_loss_wall_time
# RewardHeight_4993_log_1_ep_max_height_wall_time
# RewardHeight_4993_log_1_ep_spring_k_wall_time
# RewardHeight_4993_log_1_ep_zeta_wall_time
# RewardHeight_4993_log_1_rollout/ep_len_mean_value
# RewardHeight_4993_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_4993_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_4993_log_1_time/fps_value
# RewardHeight_4993_log_1_time/fps_wall_time
# RewardHeight_4993_log_1_train/critic_loss_value
# RewardHeight_4993_log_1_train/critic_loss_wall_time
# RewardHeight_4993_log_1_train/learning_rate_value
# RewardHeight_4993_log_1_train/learning_rate_wall_time
# RewardHeight_4993_log_1_train/actor_loss_value
# RewardHeight_4993_log_1_train/actor_loss_wall_time
# RewardHeight_5211_log_1_ep_max_height_wall_time
# RewardHeight_5211_log_1_ep_spring_k_wall_time
# RewardHeight_5211_log_1_ep_zeta_wall_time
# RewardHeight_5211_log_1_rollout/ep_len_mean_value
# RewardHeight_5211_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_5211_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_5211_log_1_time/fps_value
# RewardHeight_5211_log_1_time/fps_wall_time
# RewardHeight_5211_log_1_train/critic_loss_value
# RewardHeight_5211_log_1_train/critic_loss_wall_time
# RewardHeight_5211_log_1_train/learning_rate_value
# RewardHeight_5211_log_1_train/learning_rate_wall_time
# RewardHeight_5211_log_1_train/actor_loss_value
# RewardHeight_5211_log_1_train/actor_loss_wall_time
# RewardHeight_5225_log_1_ep_max_height_wall_time
# RewardHeight_5225_log_1_ep_spring_k_wall_time
# RewardHeight_5225_log_1_ep_zeta_wall_time
# RewardHeight_5225_log_1_rollout/ep_len_mean_value
# RewardHeight_5225_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_5225_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_5225_log_1_time/fps_value
# RewardHeight_5225_log_1_time/fps_wall_time
# RewardHeight_5225_log_1_train/critic_loss_value
# RewardHeight_5225_log_1_train/critic_loss_wall_time
# RewardHeight_5225_log_1_train/learning_rate_value
# RewardHeight_5225_log_1_train/learning_rate_wall_time
# RewardHeight_5225_log_1_train/actor_loss_value
# RewardHeight_5225_log_1_train/actor_loss_wall_time
# RewardHeight_526_log_1_ep_max_height_wall_time
# RewardHeight_526_log_1_ep_spring_k_wall_time
# RewardHeight_526_log_1_ep_zeta_wall_time
# RewardHeight_526_log_1_rollout/ep_len_mean_value
# RewardHeight_526_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_526_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_526_log_1_time/fps_value
# RewardHeight_526_log_1_time/fps_wall_time
# RewardHeight_526_log_1_train/critic_loss_value
# RewardHeight_526_log_1_train/critic_loss_wall_time
# RewardHeight_526_log_1_train/learning_rate_value
# RewardHeight_526_log_1_train/learning_rate_wall_time
# RewardHeight_526_log_1_train/actor_loss_value
# RewardHeight_526_log_1_train/actor_loss_wall_time
# RewardHeight_5279_log_1_ep_max_height_wall_time
# RewardHeight_5279_log_1_ep_spring_k_wall_time
# RewardHeight_5279_log_1_ep_zeta_wall_time
# RewardHeight_5279_log_1_rollout/ep_len_mean_value
# RewardHeight_5279_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_5279_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_5279_log_1_time/fps_value
# RewardHeight_5279_log_1_time/fps_wall_time
# RewardHeight_5279_log_1_train/critic_loss_value
# RewardHeight_5279_log_1_train/critic_loss_wall_time
# RewardHeight_5279_log_1_train/learning_rate_value
# RewardHeight_5279_log_1_train/learning_rate_wall_time
# RewardHeight_5279_log_1_train/actor_loss_value
# RewardHeight_5279_log_1_train/actor_loss_wall_time
# RewardHeight_5329_log_1_ep_max_height_wall_time
# RewardHeight_5329_log_1_ep_spring_k_wall_time
# RewardHeight_5329_log_1_ep_zeta_wall_time
# RewardHeight_5329_log_1_rollout/ep_len_mean_value
# RewardHeight_5329_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_5329_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_5329_log_1_time/fps_value
# RewardHeight_5329_log_1_time/fps_wall_time
# RewardHeight_5329_log_1_train/critic_loss_value
# RewardHeight_5329_log_1_train/critic_loss_wall_time
# RewardHeight_5329_log_1_train/learning_rate_value
# RewardHeight_5329_log_1_train/learning_rate_wall_time
# RewardHeight_5329_log_1_train/actor_loss_value
# RewardHeight_5329_log_1_train/actor_loss_wall_time
# RewardHeight_5575_log_1_ep_max_height_wall_time
# RewardHeight_5575_log_1_ep_spring_k_wall_time
# RewardHeight_5575_log_1_ep_zeta_wall_time
# RewardHeight_5575_log_1_rollout/ep_len_mean_value
# RewardHeight_5575_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_5575_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_5575_log_1_time/fps_value
# RewardHeight_5575_log_1_time/fps_wall_time
# RewardHeight_5575_log_1_train/critic_loss_value
# RewardHeight_5575_log_1_train/critic_loss_wall_time
# RewardHeight_5575_log_1_train/learning_rate_value
# RewardHeight_5575_log_1_train/learning_rate_wall_time
# RewardHeight_5575_log_1_train/actor_loss_value
# RewardHeight_5575_log_1_train/actor_loss_wall_time
# RewardHeight_5976_log_1_ep_max_height_wall_time
# RewardHeight_5976_log_1_ep_spring_k_wall_time
# RewardHeight_5976_log_1_ep_zeta_wall_time
# RewardHeight_5976_log_1_rollout/ep_len_mean_value
# RewardHeight_5976_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_5976_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_5976_log_1_time/fps_value
# RewardHeight_5976_log_1_time/fps_wall_time
# RewardHeight_5976_log_1_train/critic_loss_value
# RewardHeight_5976_log_1_train/critic_loss_wall_time
# RewardHeight_5976_log_1_train/learning_rate_value
# RewardHeight_5976_log_1_train/learning_rate_wall_time
# RewardHeight_5976_log_1_train/actor_loss_value
# RewardHeight_5976_log_1_train/actor_loss_wall_time
# RewardHeight_609_log_1_ep_max_height_wall_time
# RewardHeight_609_log_1_ep_spring_k_wall_time
# RewardHeight_609_log_1_ep_zeta_wall_time
# RewardHeight_609_log_1_rollout/ep_len_mean_value
# RewardHeight_609_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_609_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_609_log_1_time/fps_value
# RewardHeight_609_log_1_time/fps_wall_time
# RewardHeight_609_log_1_train/critic_loss_value
# RewardHeight_609_log_1_train/critic_loss_wall_time
# RewardHeight_609_log_1_train/learning_rate_value
# RewardHeight_609_log_1_train/learning_rate_wall_time
# RewardHeight_609_log_1_train/actor_loss_value
# RewardHeight_609_log_1_train/actor_loss_wall_time
# RewardHeight_621_log_1_ep_max_height_wall_time
# RewardHeight_621_log_1_ep_spring_k_wall_time
# RewardHeight_621_log_1_ep_zeta_wall_time
# RewardHeight_621_log_1_rollout/ep_len_mean_value
# RewardHeight_621_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_621_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_621_log_1_time/fps_value
# RewardHeight_621_log_1_time/fps_wall_time
# RewardHeight_621_log_1_train/critic_loss_value
# RewardHeight_621_log_1_train/critic_loss_wall_time
# RewardHeight_621_log_1_train/learning_rate_value
# RewardHeight_621_log_1_train/learning_rate_wall_time
# RewardHeight_621_log_1_train/actor_loss_value
# RewardHeight_621_log_1_train/actor_loss_wall_time
# RewardHeight_6250_log_1_ep_max_height_wall_time
# RewardHeight_6250_log_1_ep_spring_k_wall_time
# RewardHeight_6250_log_1_ep_zeta_wall_time
# RewardHeight_6250_log_1_rollout/ep_len_mean_value
# RewardHeight_6250_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_6250_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_6250_log_1_time/fps_value
# RewardHeight_6250_log_1_time/fps_wall_time
# RewardHeight_6250_log_1_train/critic_loss_value
# RewardHeight_6250_log_1_train/critic_loss_wall_time
# RewardHeight_6250_log_1_train/learning_rate_value
# RewardHeight_6250_log_1_train/learning_rate_wall_time
# RewardHeight_6250_log_1_train/actor_loss_value
# RewardHeight_6250_log_1_train/actor_loss_wall_time
# RewardHeight_6314_log_1_ep_max_height_wall_time
# RewardHeight_6314_log_1_ep_spring_k_wall_time
# RewardHeight_6314_log_1_ep_zeta_wall_time
# RewardHeight_6314_log_1_rollout/ep_len_mean_value
# RewardHeight_6314_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_6314_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_6314_log_1_time/fps_value
# RewardHeight_6314_log_1_time/fps_wall_time
# RewardHeight_6314_log_1_train/critic_loss_value
# RewardHeight_6314_log_1_train/critic_loss_wall_time
# RewardHeight_6314_log_1_train/learning_rate_value
# RewardHeight_6314_log_1_train/learning_rate_wall_time
# RewardHeight_6314_log_1_train/actor_loss_value
# RewardHeight_6314_log_1_train/actor_loss_wall_time
# RewardHeight_6702_log_1_ep_max_height_wall_time
# RewardHeight_6702_log_1_ep_spring_k_wall_time
# RewardHeight_6702_log_1_ep_zeta_wall_time
# RewardHeight_6702_log_1_rollout/ep_len_mean_value
# RewardHeight_6702_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_6702_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_6702_log_1_time/fps_value
# RewardHeight_6702_log_1_time/fps_wall_time
# RewardHeight_6702_log_1_train/critic_loss_value
# RewardHeight_6702_log_1_train/critic_loss_wall_time
# RewardHeight_6702_log_1_train/learning_rate_value
# RewardHeight_6702_log_1_train/learning_rate_wall_time
# RewardHeight_6702_log_1_train/actor_loss_value
# RewardHeight_6702_log_1_train/actor_loss_wall_time
# RewardHeight_6761_log_1_ep_max_height_wall_time
# RewardHeight_6761_log_1_ep_spring_k_wall_time
# RewardHeight_6761_log_1_ep_zeta_wall_time
# RewardHeight_6761_log_1_rollout/ep_len_mean_value
# RewardHeight_6761_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_6761_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_6761_log_1_time/fps_value
# RewardHeight_6761_log_1_time/fps_wall_time
# RewardHeight_6761_log_1_train/critic_loss_value
# RewardHeight_6761_log_1_train/critic_loss_wall_time
# RewardHeight_6761_log_1_train/learning_rate_value
# RewardHeight_6761_log_1_train/learning_rate_wall_time
# RewardHeight_6761_log_1_train/actor_loss_value
# RewardHeight_6761_log_1_train/actor_loss_wall_time
# RewardHeight_6824_log_1_ep_max_height_wall_time
# RewardHeight_6824_log_1_ep_spring_k_wall_time
# RewardHeight_6824_log_1_ep_zeta_wall_time
# RewardHeight_6824_log_1_rollout/ep_len_mean_value
# RewardHeight_6824_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_6824_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_6824_log_1_time/fps_value
# RewardHeight_6824_log_1_time/fps_wall_time
# RewardHeight_6824_log_1_train/critic_loss_value
# RewardHeight_6824_log_1_train/critic_loss_wall_time
# RewardHeight_6824_log_1_train/learning_rate_value
# RewardHeight_6824_log_1_train/learning_rate_wall_time
# RewardHeight_6824_log_1_train/actor_loss_value
# RewardHeight_6824_log_1_train/actor_loss_wall_time
# RewardHeight_6859_log_1_ep_max_height_wall_time
# RewardHeight_6859_log_1_ep_spring_k_wall_time
# RewardHeight_6859_log_1_ep_zeta_wall_time
# RewardHeight_6859_log_1_rollout/ep_len_mean_value
# RewardHeight_6859_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_6859_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_6859_log_1_time/fps_value
# RewardHeight_6859_log_1_time/fps_wall_time
# RewardHeight_6859_log_1_train/critic_loss_value
# RewardHeight_6859_log_1_train/critic_loss_wall_time
# RewardHeight_6859_log_1_train/learning_rate_value
# RewardHeight_6859_log_1_train/learning_rate_wall_time
# RewardHeight_6859_log_1_train/actor_loss_value
# RewardHeight_6859_log_1_train/actor_loss_wall_time
# RewardHeight_6880_log_1_ep_max_height_wall_time
# RewardHeight_6880_log_1_ep_spring_k_wall_time
# RewardHeight_6880_log_1_ep_zeta_wall_time
# RewardHeight_6880_log_1_rollout/ep_len_mean_value
# RewardHeight_6880_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_6880_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_6880_log_1_time/fps_value
# RewardHeight_6880_log_1_time/fps_wall_time
# RewardHeight_6880_log_1_train/critic_loss_value
# RewardHeight_6880_log_1_train/critic_loss_wall_time
# RewardHeight_6880_log_1_train/learning_rate_value
# RewardHeight_6880_log_1_train/learning_rate_wall_time
# RewardHeight_6880_log_1_train/actor_loss_value
# RewardHeight_6880_log_1_train/actor_loss_wall_time
# RewardHeight_7109_log_1_ep_max_height_wall_time
# RewardHeight_7109_log_1_ep_spring_k_wall_time
# RewardHeight_7109_log_1_ep_zeta_wall_time
# RewardHeight_7109_log_1_rollout/ep_len_mean_value
# RewardHeight_7109_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_7109_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_7109_log_1_time/fps_value
# RewardHeight_7109_log_1_time/fps_wall_time
# RewardHeight_7109_log_1_train/critic_loss_value
# RewardHeight_7109_log_1_train/critic_loss_wall_time
# RewardHeight_7109_log_1_train/learning_rate_value
# RewardHeight_7109_log_1_train/learning_rate_wall_time
# RewardHeight_7109_log_1_train/actor_loss_value
# RewardHeight_7109_log_1_train/actor_loss_wall_time
# RewardHeight_711_log_1_ep_max_height_wall_time
# RewardHeight_711_log_1_ep_spring_k_wall_time
# RewardHeight_711_log_1_ep_zeta_wall_time
# RewardHeight_711_log_1_rollout/ep_len_mean_value
# RewardHeight_711_log_1_rollout/ep_len_mean_wall_time
# RewardHeight_711_log_1_rollout/ep_rew_mean_wall_time
# RewardHeight_711_log_1_time/fps_value
# RewardHeight_711_log_1_time/fps_wall_time
# RewardHeight_711_log_1_train/critic_loss_value
# RewardHeight_711_log_1_train/critic_loss_wall_time
# RewardHeight_711_log_1_train/learning_rate_value
# RewardHeight_711_log_1_train/learning_rate_wall_time
# ...
# RewardSpecifiedHeight_8353_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8353_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8353_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8353_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8353_log_1_time/fps_value
# RewardSpecifiedHeight_8353_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8353_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8353_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8353_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8353_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8353_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8353_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_8395_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_8395_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_8395_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8395_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8395_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8395_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8395_log_1_time/fps_value
# RewardSpecifiedHeight_8395_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8395_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8395_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8395_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8395_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8395_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8395_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_8472_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_8472_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_8472_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8472_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8472_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8472_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8472_log_1_time/fps_value
# RewardSpecifiedHeight_8472_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8472_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8472_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8472_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8472_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8472_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8472_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_8663_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_8663_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_8663_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8663_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8663_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8663_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8663_log_1_time/fps_value
# RewardSpecifiedHeight_8663_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8663_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8663_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8663_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8663_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8663_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8663_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_8683_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_8683_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_8683_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8683_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8683_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8683_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8683_log_1_time/fps_value
# RewardSpecifiedHeight_8683_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8683_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8683_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8683_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8683_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8683_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8683_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_8787_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_8787_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_8787_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8787_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8787_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8787_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8787_log_1_time/fps_value
# RewardSpecifiedHeight_8787_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8787_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8787_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8787_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8787_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8787_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8787_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_8794_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_8794_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_8794_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8794_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8794_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8794_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8794_log_1_time/fps_value
# RewardSpecifiedHeight_8794_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8794_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8794_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8794_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8794_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8794_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8794_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_8895_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_8895_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_8895_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_8895_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_8895_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_8895_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_8895_log_1_time/fps_value
# RewardSpecifiedHeight_8895_log_1_time/fps_wall_time
# RewardSpecifiedHeight_8895_log_1_train/critic_loss_value
# RewardSpecifiedHeight_8895_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_8895_log_1_train/learning_rate_value
# RewardSpecifiedHeight_8895_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_8895_log_1_train/actor_loss_value
# RewardSpecifiedHeight_8895_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_906_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_906_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_906_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_906_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_906_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_906_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_906_log_1_time/fps_value
# RewardSpecifiedHeight_906_log_1_time/fps_wall_time
# RewardSpecifiedHeight_906_log_1_train/critic_loss_value
# RewardSpecifiedHeight_906_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_906_log_1_train/learning_rate_value
# RewardSpecifiedHeight_906_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_906_log_1_train/actor_loss_value
# RewardSpecifiedHeight_906_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_912_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_912_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_912_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_912_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_912_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_912_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_912_log_1_time/fps_value
# RewardSpecifiedHeight_912_log_1_time/fps_wall_time
# RewardSpecifiedHeight_912_log_1_train/critic_loss_value
# RewardSpecifiedHeight_912_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_912_log_1_train/learning_rate_value
# RewardSpecifiedHeight_912_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_912_log_1_train/actor_loss_value
# RewardSpecifiedHeight_912_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9145_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9145_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9145_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9145_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9145_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9145_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9145_log_1_time/fps_value
# RewardSpecifiedHeight_9145_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9145_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9145_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9145_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9145_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9145_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9145_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9186_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9186_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9186_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9186_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9186_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9186_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9186_log_1_time/fps_value
# RewardSpecifiedHeight_9186_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9186_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9186_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9186_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9186_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9186_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9186_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9192_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9192_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9192_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9192_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9192_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9192_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9192_log_1_time/fps_value
# RewardSpecifiedHeight_9192_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9192_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9192_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9192_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9192_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9192_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9192_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9279_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9279_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9279_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9279_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9279_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9279_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9279_log_1_time/fps_value
# RewardSpecifiedHeight_9279_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9279_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9279_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9279_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9279_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9279_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9279_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9364_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9364_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9364_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9364_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9364_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9364_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9364_log_1_time/fps_value
# RewardSpecifiedHeight_9364_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9364_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9364_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9364_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9364_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9364_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9364_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9474_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9474_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9474_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9474_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9474_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9474_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9474_log_1_time/fps_value
# RewardSpecifiedHeight_9474_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9474_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9474_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9474_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9474_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9474_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9474_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9816_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9816_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9816_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9816_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9816_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9816_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9816_log_1_time/fps_value
# RewardSpecifiedHeight_9816_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9816_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9816_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9816_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9816_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9816_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9816_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9917_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9917_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9917_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9917_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9917_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9917_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9917_log_1_time/fps_value
# RewardSpecifiedHeight_9917_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9917_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9917_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9917_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9917_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9917_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9917_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9990_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9990_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9990_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9990_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9990_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9990_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9990_log_1_time/fps_value
# RewardSpecifiedHeight_9990_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9990_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9990_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9990_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9990_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9990_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9990_log_1_train/actor_loss_wall_time
# RewardSpecifiedHeight_9993_log_1_ep_max_height_wall_time
# RewardSpecifiedHeight_9993_log_1_ep_spring_k_wall_time
# RewardSpecifiedHeight_9993_log_1_ep_zeta_wall_time
# RewardSpecifiedHeight_9993_log_1_rollout/ep_len_mean_value
# RewardSpecifiedHeight_9993_log_1_rollout/ep_len_mean_wall_time
# RewardSpecifiedHeight_9993_log_1_rollout/ep_rew_mean_wall_time
# RewardSpecifiedHeight_9993_log_1_time/fps_value
# RewardSpecifiedHeight_9993_log_1_time/fps_wall_time
# RewardSpecifiedHeight_9993_log_1_train/critic_loss_value
# RewardSpecifiedHeight_9993_log_1_train/critic_loss_wall_time
# RewardSpecifiedHeight_9993_log_1_train/learning_rate_value
# RewardSpecifiedHeight_9993_log_1_train/learning_rate_wall_time
# RewardSpecifiedHeight_9993_log_1_train/actor_loss_value
# RewardSpecifiedHeight_9993_log_1_train/actor_loss_wall_time
# Dataframe shape after:  (1000, 800)

# %% [markdown]
# ## Get the mean and standard dev for the different cases and designs

# %%
height_height_df = data.filter(like=training_cases[0]).filter(like=data_values[0])
height_height_mean_df = height_height_df.mean(axis=1)
height_height_std_df = height_height_df.std(axis=1)

height_spring_k_df = data.filter(like=training_cases[0]).filter(like=data_values[1])
height_spring_k_mean_df = height_spring_k_df.mean(axis=1)
height_spring_k_std_df = height_spring_k_df.std(axis=1)

height_zeta_df = data.filter(like=training_cases[0]).filter(like=data_values[2])
height_zeta_mean_df = height_zeta_df.mean(axis=1)
height_zeta_std_df = height_zeta_df.std(axis=1)

height_reward_df = data.filter(like=training_cases[0]).filter(like=data_values[3])
height_reward_df = height_reward_df.dropna()
height_reward_mean_df = height_reward_df.mean(axis=1)
height_reward_std_df = height_reward_df.std(axis=1)

spechei_height_df = data.filter(like=training_cases[1]).filter(like=data_values[0])
spechei_height_mean_df = spechei_height_df.mean(axis=1)
spechei_height_std_df = spechei_height_df.std(axis=1)

spechei_spring_k_df = data.filter(like=training_cases[1]).filter(like=data_values[1])
spechei_spring_k_mean_df = spechei_spring_k_df.mean(axis=1)
spechei_spring_k_std_df = spechei_spring_k_df.std(axis=1)

spechei_zeta_df = data.filter(like=training_cases[1]).filter(like=data_values[2])
spechei_zeta_mean_df = spechei_zeta_df.mean(axis=1)
spechei_zeta_std_df = spechei_zeta_df.std(axis=1)

spechei_reward_df = data.filter(like=training_cases[1]).filter(like=data_values[3])
spechei_reward_df = spechei_reward_df.dropna()
spechei_reward_mean_df = spechei_reward_df.mean(axis=1)
spechei_reward_std_df = spechei_reward_df.std(axis=1)

reward_timesteps = np.arange(4, 1000, 4)
timesteps = np.arange(len(data))

# %% [markdown]
# ## Reward vs Agent

# %%
fig = plt.figure(figsize=(6,4))
ax1 = plt.gca()
plt.subplots_adjust(bottom=0.17, left=0.17, top=0.96, right=0.96)

# Change the axis units font
plt.setp(ax1.get_ymajorticklabels(),fontsize=18)
plt.setp(ax1.get_xmajorticklabels(),fontsize=18)

# Remove the top and right border, they are not needed
ax1.spines['right'].set_visible(True)
ax1.spines['right'].set_color("black")
# ax1.spines['top'].set_color('none')

# Define the positions of the axes tick marks
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

# Manually set the x-axis limits, if necessary
# plt.xlim(0,5)

# Turn on the plot grid and set appropriate linestyle and color
ax1.grid(True, linestyle=':', color='0.75')
ax1.set_axisbelow(True)

# Define the X and Y1 axis labels
ax1.set_xlabel('Episode', fontsize=22, weight='bold', labelpad=5)
ax1.set_ylabel(r'Max Height Reward', fontsize=22, weight='bold', labelpad=10)

# Plots gain used on input to tracking of Surge
ax1.plot(reward_timesteps, height_reward_mean_df, linewidth=2, linestyle='-', label="Height = Max")
ax1.fill_between(reward_timesteps, height_reward_mean_df-(height_reward_std_df/2), height_reward_mean_df+(height_reward_std_df)/2, alpha=0.25)
# ax1.plot(x, y1, linewidth=2, linestyle='-', label=r'$y_1$', )

# Manually set the y1-axes limits, if necessary
ax1.set_ylim(bottom=None, top=0.13)


# Set up the 2nd Y-axis, using the same x-axis as the first
ax2 = ax1.twinx()

# Remove the top border, it's not needed
# ax2.spines['top'].set_color('none')

# Turn on the plot grid and set appropriate linestyle and color
ax2.grid(True, linestyle=':', color='0.75')
ax2.set_axisbelow(True) 

# Change the y2 axis units font
plt.setp(ax2.get_ymajorticklabels(), fontsize=18)

# Define the Y2 axis labels
ax2.set_ylabel(r'0.1m Height Reward', fontsize=22, weight='bold', labelpad=10)

ax2.plot(reward_timesteps, spechei_reward_mean_df, linewidth=2, linestyle='--', color = '#377eb8', label="Height = 0.01m")
ax2.fill_between(reward_timesteps, spechei_reward_mean_df-(spechei_reward_std_df/2), spechei_reward_mean_df+(spechei_reward_std_df)/2, color = '#377eb8', alpha=0.25)
# ax2.plot(x, y2, linewidth=2, linestyle='--', color = '#377eb8', label=r'$y_2$')

# Manually set the y2-axes limits, if necessary
ax2.set_ylim(bottom=None, top=1.075)

# Create the legend, then fix the fontsize
# ask matplotlib for the plotted objects and their labels
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
leg = ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext,fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
filename = 'RewVsTime_{}.svg'.format(datetime.datetime.now().strftime('%Y-%m-%d_%H%M%S'))
path = save_path / filename
if SAVE_FIG is True:
    pass
    plt.savefig(path, transparent=True)
plt.show()

# %% [markdown]
# ## Height Vs Agent

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6,4))
ax = plt.gca()

# Define the X and Y axis labels
plt.xlabel(r'Episode', fontsize=22, weight='bold', labelpad=5)
plt.ylabel(r'Height (m)', fontsize=22, weight='bold', labelpad=10)

plt.plot(timesteps, height_height_mean_df, linewidth=2, linestyle='-', label="Height = Max")
plt.fill_between(timesteps, height_height_mean_df-(height_height_std_df/2), height_height_mean_df+(height_height_std_df)/2, alpha=0.25)
plt.plot(timesteps, spechei_height_mean_df, linewidth=2, linestyle='--', label="Height = 0.01m")
plt.fill_between(timesteps, spechei_height_mean_df-(spechei_height_std_df/2), spechei_height_mean_df+(spechei_height_std_df)/2, alpha=0.25)

# uncomment below and set limits if needed
# plt.xlim(0,4)
# plt.ylim(bottom=None, top=.35)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='lower right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext,fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
filename = 'HeightVsTime_{}.svg'.format(datetime.datetime.now().strftime('%Y-%m-%d_%H%M%S'))
path = save_path / filename
if SAVE_FIG is True:
    plt.savefig(path, transparent=True)
plt.show()

# %% [markdown]
# ## Spring K

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6,4))
ax = plt.gca()

# Define the X and Y axis labels
plt.xlabel(r'Episode', fontsize=22, weight='bold', labelpad=5)
plt.ylabel(r'Spring Constant (N/m)', fontsize=22, weight='bold', labelpad=10)

plt.plot(timesteps, height_spring_k_mean_df, linewidth=2, linestyle='-', label="Height = Max")
plt.fill_between(timesteps, height_spring_k_mean_df-(height_spring_k_std_df/2), height_spring_k_mean_df+(height_spring_k_std_df)/2, alpha=0.25)
plt.plot(timesteps, spechei_spring_k_mean_df, linewidth=2, linestyle='--', label="Height = 0.01m")
plt.fill_between(timesteps, spechei_spring_k_mean_df-(spechei_spring_k_std_df/2), spechei_spring_k_mean_df+(spechei_spring_k_std_df)/2, alpha=0.25)

# uncomment below and set limits if needed
# plt.xlim(0,4)
plt.ylim(bottom=None, top=15000)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext,fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
filename = 'SpringVsTime_{}.svg'.format(datetime.datetime.now().strftime('%Y-%m-%d_%H%M%S'))
path = save_path / filename
if SAVE_FIG is True:
    plt.savefig(path, transparent=True)
    pass
plt.show()

# %% [markdown]
# ## Damping Ratio

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6,4))
ax = plt.gca()

# Define the X and Y axis labels
plt.xlabel(r'Episode', fontsize=22, weight='bold', labelpad=5)
plt.ylabel(r'Damping Ratio ($\bf{\zeta}$)', fontsize=22, weight='bold', labelpad=10)

plt.plot(timesteps, height_zeta_mean_df, linewidth=2, linestyle='-', label="Height = Max")
plt.fill_between(timesteps, height_zeta_mean_df-(height_zeta_std_df/2), height_zeta_mean_df+(height_zeta_std_df)/2, alpha=0.25)
plt.plot(timesteps, spechei_zeta_mean_df, linewidth=2, linestyle='--', label="Height = 0.01m")
plt.fill_between(timesteps, spechei_zeta_mean_df-(spechei_zeta_std_df/2), spechei_zeta_mean_df+(spechei_zeta_std_df)/2, alpha=0.25)

# uncomment below and set limits if needed
# plt.xlim(0,4)
# plt.ylim(bottom=None, top=.35)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext,fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
filename = 'ZetaVsTime_{}.svg'.format(datetime.datetime.now().strftime('%Y-%m-%d_%H%M%S'))
path = save_path / filename
if SAVE_FIG is True:
    plt.savefig(path, transparent=True)
plt.show()

# %% [markdown]
# ## Plot time series jumps of final designs

# %% [markdown]
# ### Create Empty Lists of Values

# %%
spring_ks = []
spring_ks_std = []
zetas = []
zetas_std = []

# %% [markdown]
# ### Append to the list the different values
# - You may need to reload data from the top of this file
# - Make sure not to override the lists with empty lists though

# %%
spring_ks.append(height_spring_k_mean_df.iloc[-1])
spring_ks.append(spechei_spring_k_mean_df.iloc[-1])
spring_ks_std.append(height_spring_k_std_df.iloc[-1])
spring_ks_std.append(spechei_spring_k_std_df.iloc[-1])

zetas.append(height_zeta_mean_df.iloc[-1])
zetas.append(spechei_zeta_mean_df.iloc[-1])
zetas_std.append(height_zeta_std_df.iloc[-1])
zetas_std.append(spechei_zeta_std_df.iloc[-1])

# %%
header = "spring_ks, spring_k_stds, zetas, zeta_stds"
data = np.array([spring_ks, spring_ks_std, zetas, zetas_std])
name = save_path / "final_designs.txt"
np.savetxt(name, data.transpose(), header=header, delimiter=',')

# %%
m_act = 1.003               # mass of the pogo-stick rod (kg)
m_rod = 0.175               # mass of the pogo-stick rod (kg)

spring_k = 5760

zeta = 0.075

f = 11.13         # natural freq. (rad)
A_max = 63.2      # max acceleration of actuator (m/s^2)
V_max = 2.0       # max velocity of actuator (m/s)
Distance = 0.008  # Distance to move actuator in jump command (m)
Spring_Limit = -0.008
Spacing = 0.75 * (1 / f)  # Space commands by 0.5*period of oscillation

x_init = 0.0
x_dot_init = 0.0
x_act_init = 0.0
x_act_dot_init = 0.0

heights = []
for ii in range(len(spring_ks)):
    pogo_stick = PogoODEnonlinear(m_act, m_rod, spring_ks[ii], zetas[ii], A_max, V_max, Distance, Spring_Limit, Spacing)
    x0 = [x_init, x_dot_init, x_act_init, x_act_dot_init]
    sim_time, timeseries = pogo_stick.run_simulation(x0, duration=1.0)
    heights.append(timeseries[0])

# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6.75, 4.5))
ax = plt.gca()

# Define the X and Y axis labels
plt.xlabel(r'Time (ms)', fontsize=22, weight='bold', labelpad=5)
plt.ylabel(r'Rod Height (m)', fontsize=22, weight='bold', labelpad=10)

plt.plot(np.arange(len(heights[0][0:600])), heights[0][0:600], linewidth=2, linestyle='-', label="Broad Space: Max Height")
plt.plot(np.arange(len(heights[1][0:600])), heights[1][0:600], linewidth=2, linestyle='--', label="Borad Space: 0.01m")
plt.plot(np.arange(len(heights[2][0:600])), heights[2][0:600], linewidth=2, linestyle='-.', label="Narrow Space: Max Height")
plt.plot(np.arange(len(heights[3][0:600])), heights[3][0:600], linewidth=2, linestyle=':', label="Narrow Space: 0.01m")

# uncomment below and set limits if needed
# plt.xlim(0,4)
plt.ylim(bottom=None, top=0.23)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext,fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
filename = 'TimeseriesHeight_{}.svg'.format(datetime.datetime.now().strftime('%Y-%m-%d_%H%M%S'))
path = save_path / filename
plt.savefig(path, transparent=True)
plt.show()
